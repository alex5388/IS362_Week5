# %%
import pandas as pd

# %%
unemp = pd.read_csv("Unemployment Data.csv")

# %% [markdown]
# # Compare Unemployment Rates from 2010-2019

# %% [markdown]
# # Replace NaN values with '-' to make it look prettier.

# %%
unemp = unemp.fillna('-')

# %% [markdown]
# # Appropriately name column 1

# %%
unemp = unemp.rename(columns={'Unnamed: 0':'Year'})

# %% [markdown]
# # Transpose the columns and rows for easier viewing

# %%
unemp = unemp.T

# %%
unemp
# Out:
#                     0        1        2        3        4        5        6   \
# Year                 -     1990     1991     1992     1993     1994     1995
# Advanced Economies   -  5.80058  6.72869  7.51106  7.93618   7.7159  7.26426
# Argentina            -        -        -        -        -        -        -
# Australia            -   6.9433  9.61414  10.7501  10.8662   9.7057  8.47106
# Austria              -    5.373   5.8231  5.94171  6.81138  6.54548  6.58977
# ...                 ..      ...      ...      ...      ...      ...      ...
# United States        -  5.61667     6.85  7.49167  6.90833      6.1  5.59167
# Venezuela, RB        -        -        -        -        -        -        -
# Vietnam              -        -        -        -        -        -        -
# World (WBG members)  -        -        -        -        -        -        -
# South Africa         -        -        -        -        -        -        -
#
# ...

# %%
years = unemp.iloc[0:85, 21:31]

# %% [markdown]
# # Comparing the first 5 countries unemployment rates to the rates of Advanced Economies

# %%
years.head(7)
# Out:
#                          21       22       23       24       25       26  \
# Year                   2010     2011     2012     2013     2014     2015
# Advanced Economies  8.39486  8.10169  8.21673  8.17679  7.55235  6.95794
# Argentina           7.74579  7.15389  7.21476  7.07647  7.27087  6.61139
# Australia           5.18264  5.08469  5.22371  5.67107  6.08793  6.05649
# Austria             6.92478  6.72485  6.98126  7.61586  8.36692  9.10335
# Belgium             8.30999  7.15803  7.56831  8.45583  8.53881  8.50745
# Bulgaria            9.47417    9.595  11.0892  11.3108    11.16  10.0608
#
#                          27       28       29       30
# Year                   2016     2017     2018     2019
# Advanced Economies  6.47735  5.86999  5.33591        -
# Argentina           8.46795   8.3447  9.23277        -
# Australia           5.70941  5.57145  5.30086  5.16357
# Austria             9.06136  8.51025  7.70369  7.37477
# ...

# %% [markdown]
# # Divide and compare 2-year school tuitions and 4-year school tuitions.

# %%
tuition = pd.read_csv('Tuition fee by state.csv', index_col = 0, header=2)

# %%
tuition.index.names= [None]

# %%
tuition.fillna(' ')
# Out:
#                       2004-05  2005-06  2006-07   2007-08   2008-09  2009-10  \
# Alaska
# Alabama               $3,526   $3,420   $3,351     $3,301   $3,155   $3,227
# Arkansas              $2,422   $2,480   $2,520     $2,513   $2,555   $2,703
# Arizona               $1,800   $1,907   $1,997     $1,981   $2,026   $2,180
# California            $1,044   $1,015     $871       $744     $706     $929
# Colorado              $2,867   $2,992   $2,858     $2,890   $2,838   $3,146
# Connecticut           $3,110   $3,177   $3,214     $3,323   $3,321   $3,637
# District of Columbia
# Delaware              $3,242   $3,357   $3,437     $3,521   $3,622   $3,885
# Florida               $2,301   $2,404   $2,443     $2,387   $2,551   $2,902
# Georgia               $2,682   $2,766   $2,690     $2,491   $2,341   $2,951
# Hawaii                $1,884   $1,910   $2,083     $2,287   $2,439   $2,777
# Iowa                  $3,774   $3,871   $3,852     $3,914   $3,908   $4,207
# ...

# %% [markdown]
# # Find null columns

# %%
tuition.isnull().sum()
# Out:
# 2004-05               3
# 2005-06               3
# 2006-07               3
#   2007-08             3
# 2008-09               3
# 2009-10               3
# 2010-11               3
# 2011-12               3
# 2012-13               3
# 2013-14               3
# 2014-15               3
# 2015-16               3
# 2016-17               3
# 2017-18               3
# 1-Year % Change       3
# 5-Year % Change       3
# Unnamed: 17          52
# 2004-05.1             0
# 2005-06.1             0
# 2006-07.1             0
#   2007-08 .1          0
# 2008-09.1             0
# 2009-10.1             0
# 2010-11.1             0
# 2011-12.1             0
# 2012-13.1             0
# 2013-14.1             0
# 2014-15.1             0
# 2015-16.1             0
# 2016-17.1             0
# 2017-18.1             0
# 1-Year % Change.1     0
# 5-Year % Change.1     0
# dtype: int64

# %% [markdown]
# # Table divided by years of school

# %%
two_year = tuition.iloc[:, 1:16]

# %%
four_year = tuition.iloc[:, 18:]

# %%
two_year.head()
# Out:
#             2005-06  2006-07   2007-08   2008-09  2009-10  2010-11  2011-12  \
# Alaska          NaN      NaN        NaN      NaN      NaN      NaN      NaN
# Alabama     $3,420   $3,351     $3,301   $3,155   $3,227   $3,837   $4,345
# Arkansas    $2,480   $2,520     $2,513   $2,555   $2,703   $2,835   $2,885
# Arizona     $1,907   $1,997     $1,981   $2,026   $2,180   $2,222   $2,331
# California  $1,015     $871       $744     $706     $929     $920   $1,212
#
#             2012-13  2013-14  2014-15  2015-16  2016-17  2017-18  \
# Alaska          NaN      NaN      NaN      NaN      NaN      NaN
# Alabama     $4,368   $4,350   $4,373   $4,425   $4,470   $4,487
# Arkansas    $2,985   $3,150   $3,264   $3,490   $3,593   $3,645
# Arizona     $2,355   $2,445   $2,497   $2,538   $2,603   $2,606
# California  $1,516   $1,493   $1,467   $1,459   $1,450   $1,430
#
#            1-Year % Change 5-Year % Change
# Alaska                 NaN             NaN
# ...

# %%
four_year.head()
# Out:
#            2005-06.1 2006-07.1   2007-08 .1 2008-09.1 2009-10.1 2010-11.1  \
# Alaska       $4,752    $5,045       $5,200    $5,206    $5,595    $5,907
# Alabama      $5,991    $5,901       $6,163    $6,641    $7,374    $8,279
# Arkansas     $6,239    $6,392       $6,580    $6,581    $6,797    $7,078
# Arizona      $5,555    $5,622       $5,828    $6,214    $7,450    $9,067
# California   $5,670    $5,472       $5,818    $6,049    $7,445    $8,404
#
#            2011-12.1 2012-13.1 2013-14.1 2014-15.1 2015-16.1 2016-17.1  \
# Alaska       $5,910    $6,181    $6,167    $6,307    $6,876    $7,250
# Alabama      $8,669    $9,332    $9,599    $9,740    $9,996   $10,256
# Arkansas     $7,210    $7,474    $7,599    $7,802    $8,085    $8,396
# Arizona     $10,223   $10,394   $10,561   $10,681   $10,907   $11,119
# California   $9,679    $9,601    $9,512    $9,423    $9,505    $9,462
#
#            2017-18.1 1-Year % Change.1 5-Year % Change.1
# ...

# %% [markdown]
# # Accidents Investigated by State Police in 2012

# %%
accident = pd.read_csv('2012_Vehicle_Collisions_Investigated_By_State_Police.csv')

# %% [markdown]
# # Break table down by police barrack. Using Bel Air in example.

# %%
bel_air = accident[(accident.BARRACK == 'Bel Air')]

# %% [markdown]
# # Find null values

# %%
bel_air.isnull().sum()
# Out:
# CASE_NUMBER             0
# BARRACK                 0
# ACC_DATE                0
# ACC_TIME                0
# ACC_TIME_CODE           0
# DAY_OF_WEEK             0
# ROAD                    0
# INTERSECT_ROAD          0
# DIST_FROM_INTERSECT     1
# DIST_DIRECTION         26
# CITY_NAME               3
# COUNTY_CODE             0
# COUNTY_NAME             0
# VEHICLE_COUNT          52
# PROP_DEST               0
# INJURY                  0
# COLLISION_WITH_1        0
# COLLISION_WITH_2        0
# dtype: int64

# %% [markdown]
# # remove the columns with null values

# %%
bel_air = bel_air.drop(columns=['DIST_FROM_INTERSECT','DIST_DIRECTION', 'VEHICLE_COUNT'])

# %% [markdown]
# # show comparison of vehicle accident injuries handled by the Bel Air State Police

# %%
bel_air['INJURY'].value_counts()
# Out:
# NO     827
# YES    558
# Name: INJURY, dtype: int64
